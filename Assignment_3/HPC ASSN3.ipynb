# %%
import matplotlib.pyplot as plt
import numpy as np
from TracyWidom import TracyWidom
import scipy.stats as stats
import math

#normal distribution
mu = -1
variance =1
sigma = math.sqrt(variance)
x_n = np.linspace(mu - 3*sigma, mu + 3*sigma, 1001)
y = 32*stats.norm.pdf(x_n, mu, sigma)

#Tracy Widom distribution
x = np.linspace(-10, 10, 1001)
tw1 = TracyWidom(beta=4)  # allowed beta values are 1, 2, and 4
pdf = tw1.pdf(x)
cdf = tw1.cdf(x)

r = np.random.rand(1000)
tw1_sample = tw1.cdfinv(r)

#generated eigenvalue data
file = np.loadtxt("eigs2.txt")
file2 = np.loadtxt("10keigs.txt")
eigs = file[:,1]
eigs2 = file2[:,1]

#plotting
plt.hist(tw1_sample,bins=150,color='red')#,title="Random data generated using Tracy Widom distribution.")
plt.plot(x_n, y)
#plt.savefig("TWDistHist.pdf")
plt.show()


#normal distribution
mu = 141.1
variance = 0.1
sigma = math.sqrt(variance)
x_n = np.linspace(mu - 3*sigma, mu + 3*sigma, 1000)
y = 25*stats.norm.pdf(x_n, mu, sigma)
plt.plot(x_n, y)

plt.hist(eigs,bins=150,color="blue")#,title="The largest eigenvalues of randomly generated 5000x5000 matrices.")
#plt.savefig("5kx5k_1-3keigs.pdf")
plt.show()

plt.hist(eigs2,bins=200,color="green")#plt.savefig("5kx5k_1-3keigs.pdf")

#plt.savefig("2kx2k_10keigs.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math

mu = 141
variance = 0.5
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 1000)
y = 35*2*stats.norm.pdf(x, mu, sigma)
plt.plot(x, y)
plt.show()
